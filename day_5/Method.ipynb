# %%
class student:
    def greet(self):
        print ("Hello i am student")
s1=student()
s1.greet()
s2=student()
s2.greet()
# Out:
# Hello i am student
# Hello i am student

# %%
#Method with parameters addition

# %%
#method for user input
class student:
    def add(self):
        a=int(input("Enter frist number"))
        b=int(input("Enter the secound number:"))
        print("The sum is:",a+b)
s1=student()
s1.add()
# Out:
# The sum is: 66

# %%
class student:
    def __init__ (self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print("Name is:",self.name)
        print("Age is:",self.age)
s1=student("sony",20)
s1.display()
# Out:
# Name is: sony
# Age is: 20

# %%
#Real world exple of method bank account
class BankAccount:
    def __init__(self, balance):
        self.balance = balance
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self.balance -= amount
    def display_balance(self):
        print("Current balance:", self.balance)
        account =BankAccount(1000)
        account.display_balance()
        account.deposit(500)
        account.display_balance()
        account.withdraw(200)
        account.display_balance()

# %%
#Task 1
def calc_rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)
    return area, perimeter
length =5
width =3
area, perimeter = calc_rectangle(length, width)
print("Area:", area)
print("Parameter:", perimeter)
# Out:
# Area: 15
# Parameter: 16

# %%
#Task 2
