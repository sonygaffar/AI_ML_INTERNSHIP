# %%
#Task 2: The Logic of Dependency (Independent vs. Dependent)
P_heads = 1/2
P_six = 1/6
P_both = P_heads * P_six
print("Probability of Heads and rolling a 6:", P_both)
P_first_red = 5/10
P_second_red = 4/9
P_two_reds = P_first_red * P_second_red
print("Probability of picking two Red marbles:", P_two_reds)
# Out:
# Probability of Heads and rolling a 6: 0.08333333333333333
# Probability of picking two Red marbles: 0.2222222222222222
