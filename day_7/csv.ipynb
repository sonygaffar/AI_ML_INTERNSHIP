# %%
#Creating CSV file and writing data to it
import csv
with open("data.csv", "w", newline="") as file:
    writer =csv.writer(file)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["Sony","20","Mysuru"])
    writer.writerow(["Bushra","21","Hassan"])
    writer.writerow(["Dilbar","22","Bangalore"])
    writer.writerow(["Manasa","23","Mysuru"])
print("Data written to CSV file successfully.")
# Out:
# Data written to CSV file successfully.

# %%
# To read data from CSV file
import csv
with open("data.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Sony', '20', 'Mysuru']
# ['Bushra', '21', 'Hassan']
# ['Dilbar', '22', 'Bangalore']
# ['Manasa', '23', 'Mysuru']
