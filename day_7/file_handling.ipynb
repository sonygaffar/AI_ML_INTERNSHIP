# %%
file =open ("data.tex","w")

#step 2 write data to file
file.write("This is a sample text file.\n")
file.write("This is a second line in the file.\n")
file.write("This is a third line in the file.\n")
print("Data written to file successfully.")
#close the file

file.close()
# Out:
# Data written to file successfully.

# %%
#this over write the data in te file
file=open("data.txt","w")
file.write("good morning.")
file.close()

# %%
#append write the data in te file
file=open("data.txt","a")
file.write("\n good morning.")
file.close()

# %%
#append file.py
file=open("data.txt","a")
file.write("\n This line is appended using append mode.")
file.write("\n File handling is easy in python,")
file.close()

# %%
#user input to write data in file
file=open("data.txt","a")
name=input("Enter your name:")
age=input("Enter your age:")
file.write(f"\n name:{name}, age:{age}")
file.close()

# %%
#count line in file
file=open("data.txt","r")
lines=file.readlines()
print("Total number of lines in the file:",len(lines))
file.close()
# Out:
# Total number of lines in the file: 5

# %%
# Total nuber of rows and columns in csv file
import csv
with open("data.csv","r") as file:
    reader=csv.reader(file)
    rows=list(reader)
    total_rows=len(rows)
    total_columns=len(rows[0]) 
print("Total number of rows:",total_rows)
print("Total number of columns:",total_columns)
# Out:
# Total number of rows: 5
# Total number of columns: 3

# %%
age = []
for row in rows[1:]:
    age.append(int(row[1]))
print(age)
# Out:
# [20, 21, 22, 23]
