# %%
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
name = input("Enter your name:")
print("hello how are you ",name)
# Out:
# hello how are you  sony

# %%
a=10
convert=float(a)
print(convert)
# Out:
# 10.0

# %%
x=int(input("hello:"))
y=float(input("bye:"))
print("sum",x+y)
# Out:
# sum 20.0

# %%
price=float(input("Enter product price:"))
quality=int(input("Enter quality price"))
total=price*quality
print("total bill",total)
# Out:
# total bill 400.0

# %%
name=input("Enter your name")
print("hey",name)
current_age = int(input("Enter current age in 2026: "))
age_in_2030 = current_age + 4
print(f"you will be {age_in_2030}","years old")
# Out:
# hey sony
# you will be 24 years old

# %%
name=input("Enter your name")
age=input("Enter your current age")
age=int(age)
new_age=age+4
print("Hey",name,",you will be",new_age,"Years old in 2030")
# Out:
# Hey sony ,you will be 24 Years old in 2030

# %%
total_bill_amount = input("Enter total bill: ")
total_bill_amount = float(total_bill_amount)

number_of_people = input("Enter total number of peoples: ")
number_of_people = float(number_of_people)

bill_share_per_person = total_bill_amount / number_of_people

print("Total Bill:", total_bill_amount, "Each person pays:", bill_share_per_person)
# Out:
# Total Bill: 1348.9 Each person pays: 58.64782608695653

# %%
item_name="laptop"
print(type(item_name))
quantity=10
print(type(quantity))
price=108.4
print(type(price))
in_stock=True
print(type(in_stock))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
item_name=str("Laptop")
quantity=int(12)
price=float(220000)
in_stock=bool(1)
print("Item:",item_name,",Quantity:",quantity,",price:",price,",Available:",in_stock)
# Out:
# Item: Laptop ,Quantity: 12 ,price: 220000.0 ,Available: True

# %%
x=input("Enter a number")
y=int(x)
if y%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
print("Even" if int(input("Enter a number: ")) % 2 == 0 else "Odd")
# Out:
# Even
