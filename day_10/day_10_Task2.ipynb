# %%
#Task 2: The Type Fixer (Data Type Conversion)
import pandas as pd
data = {
    "Name": ["Akash", "Rahul", "Bushra", "Priya"],
    "Price": ["$45000", "$52000", "$48000", "$51000"],
    "Date": ["2025-01-10", "2025-02-15", "2025-03-20", "2025-04-25"]
}
df = pd.DataFrame(data)
print("Original Data:")
print(df)
print("\nInitial Data Types:")
print(df.dtypes)
df["Price"] = df["Price"].str.replace("$", "", regex=False).astype(float)
df["Date"] = pd.to_datetime(df["Date"])
print("\nUpdated Data Types:")
print(df.dtypes)
print("\nCleaned Dataset:")
print(df)
# Out:
# Original Data:
#      Name   Price        Date
# 0   Akash  $45000  2025-01-10
# 1   Rahul  $52000  2025-02-15
# 2  Bushra  $48000  2025-03-20
# 3   Priya  $51000  2025-04-25
#
# Initial Data Types:
# Name     object
# Price    object
# Date     object
# dtype: object
#
# Updated Data Types:
# Name             object
# Price           float64
# Date     datetime64[ns]
# dtype: object
#
# Cleaned Dataset:
#      Name    Price       Date
# 0   Akash  45000.0 2025-01-10
# 1   Rahul  52000.0 2025-02-15
# 2  Bushra  48000.0 2025-03-20
# 3   Priya  51000.0 2025-04-25
