# %%
import csv
data = [
    ["EmployeeID", "Name", "Department", "YearsExperience", "Salary"],
    [1, "Akash", "IT", 5, 70000],
    [2, "Poornima", "HR", 8, 80000],
    [3, "Sony", "Finance", 2, 60000],
    [4, "Emily", "IT", 6, 75000],
    [5, "David", "HR", 10, 90000],
    [6, "Sarah", "Finance", 4, 65000],
    [7, "Chris", "IT", "", 72000],  
    [8, "Anna", "HR", 7, ""]      
    ]
with open("customer_orders.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)
print("customer_orders.csv file created successfully!")
import pandas as pd
import numpy as np
df = pd.read_csv("customer_orders.csv")
print(df)
# Out:
# customer_orders.csv file created successfully!
#    EmployeeID      Name Department  YearsExperience   Salary
# 0           1     Akash         IT              5.0  70000.0
# 1           2  Poornima         HR              8.0  80000.0
# 2           3      Sony    Finance              2.0  60000.0
# 3           4     Emily         IT              6.0  75000.0
# 4           5     David         HR             10.0  90000.0
# 5           6     Sarah    Finance              4.0  65000.0
# 6           7     Chris         IT              NaN  72000.0
# 7           8      Anna         HR              7.0      NaN
