# %%
#example for dirty data
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", None],
    "Age": [25, 30, None, 35, 40],
    "City": ["New York", None, "Los Angeles", "Chicago", "Houston"]
}
df = pd.DataFrame(data)
print("Dirty Data:")
print(df.dtypes)
# Out:
# Dirty Data:
# Name     object
# Age     float64
# City     object
# dtype: object
